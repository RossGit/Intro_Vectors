# %%
#1
import numpy as np

u = np.array([1,-2,4])
v = np.array([3,5,1])
w = np.array([2,1,-3])

print("Given the following vectors:")
print("u : ",u)
print("v : ",v)
print("w : ",w)
print("Find: ")
print("a.) 3𝐮-2𝐯: ", (3*u) - (2*v))
print("b.) 5𝐮+3𝐯-4𝐰: ", (5*u) + (3*v) - (4*w))
print('c.) u.v: ', u.dot(v))
print('c.) v.w: ', v.dot(w))
print('c.) u.w: ', u.dot(w))
print('d.) ||u||: ', np.sqrt(u.dot(u)))
print('d.) ||v||: ', np.sqrt(v.dot(v)))
print('d.) ||w||: ', np.sqrt(w.dot(w)))
print("e.) angle theta between u and v:",u.dot(v)/(np.linalg.norm(u)*np.linalg.norm(v)))
print("f.) angle alpha between v and w:",v.dot(w)/(np.linalg.norm(v)*np.linalg.norm(w)))
print("g.) angle theta between u and w:",u.dot(w)/(np.linalg.norm(u)*np.linalg.norm(w)))
print("h.) d(u,v): ", np.linalg.norm(u-v))
print("i.) d(w,v): ", np.linalg.norm(w-v))
print("j.) d(u,w): ", np.linalg.norm(u-w))
print("k.) proj(u,v): ",u.dot(v)*v/(np.linalg.norm(v)**2) )
print("l.) proj(w,v): ",w.dot(v)*v/(np.linalg.norm(v)**2) )
print("k.) proj(u,w): ",u.dot(w)*w/(np.linalg.norm(w)**2) )
# Out:
# Given the following vectors:
# u :  [ 1 -2  4]
# v :  [3 5 1]
# w :  [ 2  1 -3]
# Find:
# a.) 3𝐮-2𝐯:  [ -3 -16  10]
# b.) 5𝐮+3𝐯-4𝐰:  [ 6  1 35]
# c.) u.v:  -3
# c.) v.w:  8
# c.) u.w:  -12
# d.) ||u||:  4.58257569495584
# d.) ||v||:  5.916079783099616
# d.) ||w||:  3.7416573867739413
# e.) angle theta between u and v: -0.11065666703449763
# f.) angle alpha between v and w: 0.36140316116210053
# g.) angle theta between u and w: -0.6998542122237653
# h.) d(u,v):  7.874007874011811
# i.) d(w,v):  5.744562646538029
# j.) d(u,w):  7.681145747868608
# k.) proj(u,v):  [-0.25714286 -0.42857143 -0.08571429]
# l.) proj(w,v):  [0.68571429 1.14285714 0.22857143]
# k.) proj(u,w):  [-1.71428571 -0.85714286  2.57142857]

# %% [markdown]
# Manual Solution:
# a.)
# \begin{align}
#     3\textbf{u}-2\textbf{v} &= 3\begin{bmatrix}
#            1 \\
#            -2 \\
#            4
#          \end{bmatrix} - 2 \begin{bmatrix}
#            3 \\
#            5 \\
#            1
#          \end{bmatrix}= \begin{bmatrix}
#            3 \\
#            -6 \\
#            12
#          \end{bmatrix} + \begin{bmatrix}
#            6 \\
#            10 \\
#            2
#          \end{bmatrix} = \begin{bmatrix}
#            -3 \\
#            -16 \\
#            10
#          \end{bmatrix}
#   \end{align}
#
#
#
#   b.)
#   \begin{align}
#     5\textbf{u}+3\textbf{v}-4\textbf{w} &= 5\begin{bmatrix}
#            1 \\
#            -2 \\
#            4
#          \end{bmatrix} +3 \begin{bmatrix}
#            3 \\
#            5 \\
#            1
#          \end{bmatrix} -4 \begin{bmatrix}
#            2 \\
#            1 \\
#            -3
#          \end{bmatrix}= \begin{bmatrix}
#            5 \\
#            -10 \\
#            20
#          \end{bmatrix} + \begin{bmatrix}
#            9 \\
#            15 \\
#             3
#          \end{bmatrix}- \begin{bmatrix}
#            8 \\
#            4\\
#            -12
#          \end{bmatrix} = \begin{bmatrix}
#            6 \\
#            1 \\
#            35
#          \end{bmatrix}
#   \end{align}
#  c.)
#   \begin{align}
#       u . v = 1(3) + -2(5) + 4(1)  = 3 + (-10) + 4 = -3
#   \end{align}
#   \begin{align}
#       v . w = 3(2) + 5(1) + 1(-3)  = 6 + 5 + (-3) = 8
#   \end{align}
#   \begin{align}
#       u . w = 1(2) + -2(1) + 4(-3)  = 2 + (-2) + (-12) = -12
#   \end{align}
#
#   d.)
#   \begin{align} ||\textbf{u}|| = \sqrt{(1)^2 + (-2)^2 + (4)^2} = \sqrt{1+4+16} = \sqrt{21} \end{align}
#   \begin{align} ||\textbf{v}|| = \sqrt{(3)^2 + (5)^2 + (1)^2} = \sqrt{9+25+1} = \sqrt{35} \end{align}
#   \begin{align} ||\textbf{w}|| = \sqrt{(2)^2 + (1)^2 + (-3)^2} = \sqrt{4+1+9} = \sqrt{15} \end{align}
#
#   e.)
#   \cos{\theta}=\frac{\textbf{u} \cdotp \textbf{v}}{||\textbf{u}|| \ ||\textbf{v}||} = \frac{1(2)+(-2)(4)+3(5)}{\sqrt{1^2+(-2)^2+3^2}\sqrt{2^2+4^2+5^2}} = \frac{9}{\sqrt{14}\sqrt{45}}

# %%
#2
import numpy as np

u = np.array([1,3,-4])
v = np.array([2,1,5])
w = np.array([3,-2,6])

print("Given the following vectors:")
print("u : ",u, "\u209C")
print("v : ",v, "\u209C")
print("w : ",w, "\u209C")
print("Find: ")
print("a.) 3𝐮-2𝐯: ", (3*u) - (2*v))
print("b.) 5𝐮+3𝐯-4𝐰: ", (5*u) + (3*v) - (4*w))
print('c.) u.v: ', u.dot(v))
print('c.) v.w: ', v.dot(w))
print('c.) u.w: ', u.dot(w))
print('d.) ||u||: ', np.sqrt(u.dot(u)))
print('d.) ||v||: ', np.sqrt(v.dot(v)))
print('d.) ||w||: ', np.sqrt(w.dot(w)))
print("e.) angle theta between u and v:",u.dot(v)/(np.linalg.norm(u)*np.linalg.norm(v)))
print("f.) angle alpha between v and w:",v.dot(w)/(np.linalg.norm(v)*np.linalg.norm(w)))
print("g.) angle theta between u and w:",u.dot(w)/(np.linalg.norm(u)*np.linalg.norm(w)))
print("h.) d(u,v): ", np.linalg.norm(u-v))
print("i.) d(w,v): ", np.linalg.norm(w-v))
print("j.) d(u,w): ", np.linalg.norm(u-w))
print("k.) proj(u,v): ",u.dot(v)*v/(np.linalg.norm(v)**2) )
print("l.) proj(w,v): ",w.dot(v)*v/(np.linalg.norm(v)**2) )
print("k.) proj(u,w): ",u.dot(w)*w/(np.linalg.norm(w)**2) )
# Out:
# Given the following vectors:
# u :  [ 1  3 -4] ₜ
# v :  [2 1 5] ₜ
# w :  [ 3 -2  6] ₜ
# Find:
# a.) 3𝐮-2𝐯:  [ -1   7 -22]
# b.) 5𝐮+3𝐯-4𝐰:  [ -1  26 -29]
# c.) u.v:  -15
# c.) v.w:  34
# c.) u.w:  -27
# d.) ||u||:  5.0990195135927845
# d.) ||v||:  5.477225575051661
# d.) ||w||:  7.0
# e.) angle theta between u and v: -0.5370861555295747
# f.) angle alpha between v and w: 0.8867889026274118
# g.) angle theta between u and w: -0.7564479498187099
# h.) d(u,v):  9.273618495495704
# i.) d(w,v):  3.3166247903554
# j.) d(u,w):  11.357816691600547
# k.) proj(u,v):  [-1.  -0.5 -2.5]
# l.) proj(w,v):  [2.26666667 1.13333333 5.66666667]
# k.) proj(u,w):  [-1.65306122  1.10204082 -3.30612245]

# %% [markdown]
# #4
# import numpy as np
#
# u = np.array([5,-7])
# v = np.array([1,2,-2,4])
# w = np.array([1/2, -1/3,3/4])
# print("Normalize the given vectors:")
# print("u : ",u)
# print("v : ",v)
# print("w : ",w)
# print("Normalized forms: ")
# print("u' : ", u/np.linalg.norm(u))
# print("v' : ", v/np.linalg.norm(v))
# print("w' : ", w/np.linalg.norm(w))

# %%
#5
import numpy as np

u = np.array([1,2,-2])
v = np.array([3,-12,4])
k = -3

print("Given the following vectors and scalar: ")
print("u : ",u)
print("v : ",v)
print("k = ",k)
print("Find the following: ")
print("||u||, ||v||, ||u+v||, ||ku||")
print("||u|| : " , np.sqrt(u.dot(u)))
print("||v|| : " , np.sqrt(v.dot(v)))
print("||u+v|| : " , np.sqrt((u+v).dot(u+v)))
print("||ku|| : " , np.sqrt((u.dot(k)).dot(u.dot(k))))
# Out:
# Given the following vectors and scalar:
# u :  [ 1  2 -2]
# v :  [  3 -12   4]
# k =  -3
# Find the following:
# ||u||, ||v||, ||u+v||, ||ku||
# ||u|| :  3.0
# ||v|| :  13.0
# ||u+v|| :  10.954451150103322
# ||ku|| :  9.0

# %% [markdown]
# #6
#
# print("Find k so that u and v are orthogonal:")
# print("a.)")
# print("u : [3, k, -2]")
# print("v : [6, -4, -3]")
# print("u.v = (3)(6) + (-4)(k) + (-2)(-3) = 0")
# print("18 + (-4k) + 6 = 0")
# print("4k = 24")
# print("(4k) / 4 = (24) / 4")
# print("k = 6")
# print(" ")
# print(" ")
# print("b.)")
# print("u : [5, k, -4, 2]")
# print("v : [1, -3, 2, 2k] ")
# print("u.v = (5)(1) + (-3)k + (-4)(2) + (2)2k = 0")
# print("5 + (-3k) + (-8) + 4k = 0")
# print("4k - 3k = (-5) + 8")
# print("k = 3")
# print(" ")
# print(" ")
# print("c.)")
# print("u : [1, 7, k+2, -2]")
# print("v : [3, k, -3, k]")
